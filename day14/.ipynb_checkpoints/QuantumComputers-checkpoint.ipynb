# %%
# quantum computers and quantum machine learning

# %%
#Teleportation
#Tunneling
#Superposition
#Entaglement
#Quantum comm.
#Quantum cryptograpy

# %%
pip install qiskit
# Out:
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.6 MB 9.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.4/8.6 MB 9.7 MB/s eta 0:00:01
#    ------------------------- -------------- 5.5/8.6 MB 9.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.6/8.6 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 8.8 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 9.6 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [stevedore]
#    ---------------------------------------- 0/3 [stevedore]
#    ---------------------------------------- 0/3 [stevedore]
#    ---------------------------------------- 0/3 [stevedore]
#    ---------------------------------------- 0/3 [stevedore]
# ...

# %%
pip install qiskit_aer
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 4.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.6 MB 5.2 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.6 MB 5.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.6 MB 5.3 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.6 MB 5.1 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.6 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 5.0 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pylatexenc
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136928 sha256=52760a99c0b3f7a4b7e15c87c204470e31a4c3e1007a3459382564cb855992b7
#   Stored in directory: c:\users\kullanıcı\appdata\local\pip\cache\wheels\3c\d9\c1\bb2a15d13c742b9035ef7ae6ebe236af270b1d1d9b386dcd5e
# Successfully built pylatexenc
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Hadamart Gate 2 biti super position

# %%
from qiskit import QuantumCircuit
qc=QuantumCircuit(2,2)
qc.h(0)
qc.measure(0,0)
qc.draw('mpl')

# %%
from qiskit.visualization import plot_bloch_multivector, plot_state_city, plot_histogram
from qiskit.quantum_info import Statevector, partial_trace, DensityMatrix

# %%
state= Statevector.from_instruction(qc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 state= Statevector.from_instruction(qc)
#
# NameError: name 'Statevector' is not defined

# %%
qc = QuantumCircuit(1)
qc.x(0)
display(qc.draw('mpl'))
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)  # Bloch sphere for |1>

# %%
from qiskit import QuantumCircuit 
qc=QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.measure([0,1],[0,1])
qc.draw('mpl')
06:29:40	Zafer Acar:	from qiskit import QuantumCircuit
qc=QuantumCircuit(3,3)
qc.h(1)
qc.cx(1,2)
qc.cx(0,1)
qc.h(0)
qc.measure([0,1],[0,1])
qc.cx(1,2)
qc.cz(0,2)
qc.measure(2,2)
qc.draw('mpl')
# Out:
#   Cell In[14], line 7
#     06:29:40	Zafer Acar:	from qiskit import QuantumCircuit
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
from qiskit import QuantumCircuit # QUantum devreleri 
qc=QuantumCircuit(1,1)
qc.x(0)
qc.measure(0,0)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit # QUantum devreleri 
qc=QuantumCircuit(2,2)
qc.h([0,1])
qc.measure([0,1],[0,1])
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit # QUantum devreleri 
qc=QuantumCircuit(3,3)
qc.h(0)
qc.cx(0,1)
qc.cx(0,1)

qc.measure([0,1,2],[0,1,2])
qc.draw('mpl')

# %%
from qiskit.circuit.library import QFT
from qiskit import QuantumCircuit
qc = QuantumCircuit(3)
qc.append(QFT(3), [0, 1, 2])
qc.draw('mpl')
06:46:31	Zafer Acar:	# Superposition: H|0>
qc = QuantumCircuit(1,1)
qc.h(0)
display(qc.draw('mpl'))
sv = Statevector.from_instruction(qc)
print('Statevector:', sv)
display(plot_bloch_multivector(sv))
print('Probabilities:', sv.probabilities_dict())
# Interference: H then H again -> |0> with prob ~1
qc2 = QuantumCircuit(1,1)
qc2.h(0)
qc2.h(0)
qc2.measure(0,0)
sim = Aer.get_backend('aer_simulator')
compiled = transpile(qc2, sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
display(qc2.draw('mpl'))
plot_histogram(counts)
# Out:
#   Cell In[19], line 6
#     06:46:31	Zafer Acar:	# Superposition: H|0>
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
from qiskit import QuantumCircuit # QUantum devreleri 
qc=QuantumCircuit(3,1)
qc.h([0,1,2])
qc.cz(0,2)
qc.cz(1,2)
qc.h([0,1])
qc.measure(0,0)
qc.draw('mpl')

# %%
from qiskit import QuantumCircuit, transpile
# Superposition: H|0>
qc = QuantumCircuit(1,1)
qc.h(0)
display(qc.draw('mpl'))
sv = Statevector.from_instruction(qc)
print('Statevector:', sv)
display(plot_bloch_multivector(sv))
print('Probabilities:', sv.probabilities_dict())

# Interference: H then H again -> |0> with prob ~1
qc2 = QuantumCircuit(1,1)
qc2.h(0)
qc2.h(0)
qc2.measure(0,0)
sim = Aer.get_backend('aer_simulator')
compiled = transpile(qc2, sim)
result = sim.run(compiled, shots=1024).result()
counts = result.get_counts()
display(qc2.draw('mpl'))
plot_histogram(counts)
# Out:
# Statevector: Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# Probabilities: {np.str_('0'): np.float64(0.4999999999999999), np.str_('1'): np.float64(0.4999999999999999)}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 16
#      14 qc2.h(0)
#      15 qc2.measure(0,0)
# ---> 16 sim = Aer.get_backend('aer_simulator')
#      17 compiled = transpile(qc2, sim)
#      18 result = sim.run(compiled, shots=1024).result()
#
# NameError: name 'Aer' is not defined
