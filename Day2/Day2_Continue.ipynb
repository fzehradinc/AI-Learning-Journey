# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 294          295         0       3
# 702          703         0       3
# 812          813         0       2
# 311          312         1       1
# 875          876         1       3
# 31            32         1       1
# 221          222         0       2
# 813          814         0       3
# 253          254         0       3
# 889          890         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 294                                Mineff, Mr. Ivan    male  24.0      0
# 702                           Barbara, Miss. Saiide  female  18.0      0
# 812                       Slemen, Mr. Richard James    male  35.0      0
# 311                      Ryerson, Miss. Emily Borie  female  18.0      2
# 875                Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ...

# %%
df.tail(6)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum() #hangi sutünda kaç boş veri olduğunu gösterir
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe() #istatistik
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ist=df.describe()

# %%
ist.to_csv('istatistik.xlsx')

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ist.to_csv('istatistik.xlsx')

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df[500:600]
# Out:
#      PassengerId  Survived  Pclass  \
# 500          501         0       3
# 501          502         0       3
# 502          503         0       3
# 503          504         0       3
# 504          505         1       1
# ..           ...       ...     ...
# 595          596         0       3
# 596          597         1       2
# 597          598         0       3
# 598          599         0       3
# 599          600         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 500                              Calic, Mr. Petar    male  17.0      0      0
# 501                           Canavan, Miss. Mary  female  21.0      0      0
# 502                O'Sullivan, Miss. Bridget Mary  female   NaN      0      0
# 503                Laitinen, Miss. Kristina Sofia  female  37.0      0      0
# 504                         Maioni, Miss. Roberta  female  16.0      0      0
# ...

# %%
df.loc[0:1,['Name','Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0

# %%
df[df['Age']>25]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns=df.columns.str.upper()

# %%
df.sample()
# Out:
#      PASSENGERID  SURVIVED  PCLASS                           NAME     SEX  \
# 369          370         1       1  Aubart, Mme. Leontine Pauline  female
#
#       AGE  SIBSP  PARCH    TICKET  FARE CABIN EMBARKED
# 369  24.0      0      0  PC 17477  69.3   B35        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PASSENGERID  891 non-null    int64
#  1   SURVIVED     891 non-null    int64
#  2   PCLASS       891 non-null    int64
#  3   NAME         891 non-null    object
#  4   SEX          891 non-null    object
#  5   AGE          714 non-null    float64
#  6   SIBSP        891 non-null    int64
#  7   PARCH        891 non-null    int64
#  8   TICKET       891 non-null    object
#  9   FARE         891 non-null    float64
#  10  CABIN        204 non-null    object
#  11  EMBARKED     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['FARE'].std(),df['FARE'].mean()
# Out:
# (49.693428597180905, np.float64(32.204207968574636))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 787A-E273
#
#  Directory of C:\Users\Kullan�c�\Documents\Yapay-Zeka\Day2
#
# 31.12.2025  22:10    <DIR>          .
# 26.12.2025  16:11    <DIR>          ..
# 31.12.2025  20:42    <DIR>          .ipynb_checkpoints
# 28.12.2025  08:30           732.191 combine.csv
# 28.12.2025  08:28            55.966 corona_dat.csv
# 31.12.2025  21:17               555 istatistik.xlsx
# 28.12.2025  08:30           620.722 Methane_final.csv
# 31.12.2025  20:42                 0 new.txt
# 28.12.2025  08:28           131.528 supermarket.csv
# 28.12.2025  08:30            62.086 train.csv
# 31.12.2025  22:10            57.563 Untitled.ipynb
#                8 File(s)      1.660.611 bytes
#                3 Dir(s)  418.318.364.672 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\Kullanıcı\\Documents\\Yapay-Zeka\\Day2'

# %%
x=np.arange(20)
y=np.random.normal(10,1,20)
z=np.random.normal(10,2,20)

# %%
plt.plot(x,y, label='Y');
plt.plot(x,z, label='Z');
plt.title('xin z ve y ye göre değişimi')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# %%
plt.scatter(x,y, marker='*')

# %%
fig=plt.figure(figsize=(10,6))

# %%
df=pd.read_csv('supermarket.csv')

# %% [markdown]
# ### EDA - explanatory Data Analysis

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Total'].max()
# Out:
# 1042.65

# %%
#aslında veride olmayan ancak veriyi kullanarak yeni sutunlar olusturma isi

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['day']=(df['Date']).dt.day
df['year']=(df['Date']).dt.year

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
# pickle = Tursu
df.to_csv('fe.csv')

# %%
df['month_name']=df['Date'].dt.month_name()

# %%
df['weekday']=df['Date'].dt.day_name()
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.countplot(x=df['month_name'],hue=df['month_name'])
# Out:
# <Axes: xlabel='month_name', ylabel='count'>

# %%
df['month_name'].value_counts()
# Out:
# month_name
# January     352
# March       345
# February    303
# Name: count, dtype: int64

# %%
sns.countplot(x=df['weekday'],hue=df['weekday'])
plt.xticks(rotation=90);

# %%
sns.countplot(x=df['Product line'],hue=df['Gender'])
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['Branch'], hue=df['Product line']);
plt.legend(loc=10)

# %%
sns.boxplot(x='Branch',y='Total',data=df); #outlier bulmak için boxplot çizilir

# %%
sns.kdeplot(x=df['Total'])
# Out:
# <Axes: xlabel='Total', ylabel='Density'>

# %%
sns.pairplot(df,hue=é

# %%
plt.savefig('supermarket.png')

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
df=yf.download(['TSLA','AAPL'],start='2023-1-1',end='2025-12-28')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
df.head()
# Out:
# Price            Close                    High                     Low  \
# Ticker            AAPL        TSLA        AAPL        TSLA        AAPL
# Date
# 2023-01-03  123.211205  108.099998  128.954553  118.800003  122.324579
# 2023-01-04  124.482033  113.639999  126.747853  114.589996  123.221057
# 2023-01-05  123.161949  110.339996  125.871079  111.750000  122.905819
# 2023-01-06  127.693565  113.059998  128.353606  114.389999  123.033867
# 2023-01-09  128.215698  119.769997  131.427258  123.519997  127.959568
#
# Price                         Open                 Volume
# Ticker            TSLA        AAPL        TSLA       AAPL       TSLA
# Date
# 2023-01-03  104.639999  128.343772  118.470001  112117500  231402800
# 2023-01-04  107.519997  125.004155  109.110001   89113600  180389000
# 2023-01-05  107.160004  125.240591  110.510002   80962700  157986300
# 2023-01-06  101.809998  124.137225  103.000000   87754700  220911100
# ...

# %%
df['Close'].plot();

# %%
df=yf.download(['QNBTR.IS','ASELS.IS','GARAN.IS'],start='2023-1-1',end='2025-12-28')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df['Close'].plot();

# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytrends.request import TrendReq
pt=TrendReq()

# %%
keywords=['Erdogan','Kilicdaroglu']
pt.build_payload(keywords, timeframe='today 5-y')

# %%
df=pt.interest_over_time()
# Out:
# C:\Anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
del df['isPartial']

# %%
df.head()
# Out:
#             Erdogan  Kilicdaroglu
# date
# 2020-12-27        9             0
# 2021-01-03        8             0
# 2021-01-10        9             0
# 2021-01-17        8             0
# 2021-01-24        8             0

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
