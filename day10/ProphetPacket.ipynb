# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\anaconda3\lib\site-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\anaconda3\lib\site-packages (from prophet) (2.3.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\anaconda3\lib\site-packages (from prophet) (3.10.6)
# Requirement already satisfied: pandas>=1.0.4 in c:\anaconda3\lib\site-packages (from prophet) (2.3.3)
# Requirement already satisfied: holidays<1,>=0.25 in c:\anaconda3\lib\site-packages (from prophet) (0.90)
# Requirement already satisfied: tqdm>=4.36.1 in c:\anaconda3\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in c:\anaconda3\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\anaconda3\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: colorama in c:\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('DailyDelhiClimateTrain.csv')

# %%
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
fig=px.line(df, x='date', y='meantemp')
fig.show()

# %%
fig=px.line(df, x='date', y='humidity')
fig.show()

# %%
fig=px.line(df, x='date', y='wind_speed')
fig.show()

# %%
fig=px.scatter(df, x='humidity', y='meantemp', trendline='ols')
fig.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df['date']=pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df['year']=df['date'].dt.year
df['month']=df['date'].dt.month

# %%
df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.figure(figsize=(15,10))
sns.lineplot(df, x='month', y='meantemp', hue='year')
# Out:
# <Axes: xlabel='month', ylabel='meantemp'>

# %%
forecast=df.rename(columns={'date':'ds', 'meantemp':'y'})

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
model=Prophet()

# %%
model.fit(forecast)
# Out:
# 13:10:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:10:55 - cmdstanpy - INFO - Chain [1] done processing

# %%
tahmin = model.predict(forecast)

# %%
plot_plotly(model,tahmin)
