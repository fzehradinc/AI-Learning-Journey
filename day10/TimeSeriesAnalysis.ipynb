# %%
#Zamana bağlı veri analizi

# %%
import pandas as pd
from datetime import  date, timedelta
import datetime
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
df=pd.read_csv('adidas-quarterly-sales.csv')

# %%
df.head()
# Out:
#   Time Period  Revenue
# 0      2000Q1     1517
# 1      2000Q2     1248
# 2      2000Q3     1677
# 3      2000Q4     1393
# 4      2001Q1     1558

# %%
import plotly.express as px
import numpy as np

# %%
px.line(df, x='Time Period', y='Revenue')

# %%
result=seasonal_decompose(df['Revenue'], model='multiplicative', period=30)
fig=result.plot()
firg.set_size_inches(15,30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 result=seasonal_decompose(df['Revenue'], model='multiplicative', period=30)
#       2 fig=result.plot()
# ----> 3 firg.set_size_inches(15,30)
#
# NameError: name 'firg' is not defined

# %%
model=sm.tsa.statespace.SARIMAX(df['Revenue'])
result=model.fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Revenue   No. Observations:                   88
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -685.939
# Date:                Fri, 13 Feb 2026   AIC                           1375.877
# Time:                        11:56:30   BIC                           1380.832
# Sample:                             0   HQIC                          1377.874
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9878      0.014     68.840      0.000       0.960       1.016
# sigma2      3.324e+05   4.14e+04      8.028      0.000    2.51e+05    4.14e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.98   Jarque-Bera (JB):                 7.84
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               3.78   Skew:                             0.50
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predictions=result.predict(len(df), len(df)+7)
predictions
# Out:
# 88    5074.368263
# 89    5012.500150
# 90    4951.386350
# 91    4891.017666
# 92    4831.385014
# 93    4772.479421
# 94    4714.292020
# 95    4656.814057
# Name: predicted_mean, dtype: float64

# %%
df['Revenue'].plot()
predictions.plot()
# Out:
# <Axes: >
